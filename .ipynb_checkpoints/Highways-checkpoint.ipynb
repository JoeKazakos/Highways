# %%
import random
import networkx as nx
import matplotlib.pyplot as plt

# %%
def createGridGraph(sideLength):
    maxX = sideLength
    maxY = maxX

    network = nx.grid_2d_graph(maxX,maxY)

    newLocations ={}
    for node in network.nodes(): 
        newLocation = (node[0]/maxY*100,node[1]/maxX*100)
        newLocations[node] = newLocation

    nx.set_node_attributes(network,'pos',newLocations)
    pos = nx.get_node_attributes(network,'pos')
    
    nx.set_edge_attributes(network,'weight',100)
    nx.set_edge_attributes(network,'color','black')
    return network

# %%
def getRandomNode(graph):
    node = random.choice(graph.nodes())
    return node

# %%
def getRandomSourceTarget(graph,source,target):
    if source == None and target == None:
        rand1 = getRandomNode(graph)
        rand2 = getRandomNode(graph)
    elif source  == None or target == None:
        if source == None:
            rand1 = source
            rand2= getRandomNode(graph)
        else:
            rand1 = target
            rand2 = getRandomNode(graph)        
        
        
    while rand1 == rand2:
        rand2 = getRandomNode(graph)
        
    sourceTarget = (rand1,rand2)
    return sourceTarget

# %%
def getPath(graph,source=None,target=None):
    (source,target) = getRandomSourceTarget(graph,source,target)
    path = nx.shortest_path(graph,source=source,target=target,weight='weight')
    path_edges = list(zip(path[:-1],path[1:]))
    return path_edges

# %%
def adjustWeights(graph,path,weightAdjust=1,minWeight=None):
    for v in path:
        if not graph.has_edge(*v):
            v=(v[1],v[0])
        graph.get_edge_data(*v)['weight'] = graph.get_edge_data(*v)['weight']*weightAdjust
        if minWeight is not None and graph.get_edge_data(*v)['weight'] < minWeight:
            graph.get_edge_data(*v)['weight'] = minWeight

# %%
def displayGraphPath(network,path=None):
    
    nx.set_edge_attributes(network,'color','black')
    edge_colors = nx.get_edge_attributes(network,'weight')
    
    pos = nx.get_node_attributes(network,'pos')
    edgeColorList = list(edge_colors.values())
    edgeList = list(edge_colors.keys())
    nx.draw_networkx_edges(network,pos,width=5,edge_color=edgeColorList,edgelist=edgeList,edge_cmap=plt.cm.Blues_r)
    
    
#    if path is not None:
#        nx.draw_networkx_edges(network,pos,width=10,edge_color='red',edgelist=path)
#        path_edges_colors = dict.fromkeys(path,'red')
    
#print(edge_colors.keys())
#print(edge_colors.values())
    plt.show()

# %%
def correctWeightError(network,defaultWeight=100,errorCorrectThreshold=2,minWeight=50,maxWeight=200):
    weightAttributes = nx.get_edge_attributes(network,'weight')
    
    weightList = list(weightAttributes.values())
    
    #only need to calculate once
    numOfEdges = len(weightList)
    totalCorrectWeight = numOfEdges*defaultWeight
    
    weightList = list(weightAttributes.values())
    sumOfWeights = sum(weightList)
    averageError = (sumOfWeights-totalCorrectWeight)/numOfEdges
    print(averageError)
    
    while abs(averageError) > errorCorrectThreshold:
        print("performing error correct")
        for k,v in weightAttributes.items():
            weightAttributes[k] -= averageError
            if weightAttributes[k] < minWeight:
                weightAttributes[k] = minWeight
            if weightAttributes[k] > maxWeight:
                weightAttributes[k] = maxWeight
            
            
        weightList = list(weightAttributes.values())
        sumOfWeights = sum(weightList)
        averageError = (sumOfWeights-totalCorrectWeight)/numOfEdges
    
    nx.set_edge_attributes(network,'weight',weightAttributes)

# %%
def randomizeWeights(network,minWeight=1,maxWeight=400):
    #apply random weights
    weights = nx.get_edge_attributes(network,'weight')
    for w in weights.keys():
        weights[w] = random.uniform(minWeight,maxWeight)
    nx.set_edge_attributes(network,'weight',weights)

# %%
def saveImage(graph,filename):
    edge_colors = nx.get_edge_attributes(graph,'weight')
    pos = nx.get_node_attributes(graph,'pos')
    edgeColorList = list(edge_colors.values())
    edgeList = list(edge_colors.keys())
   
    nx.draw_networkx_edges(graph,pos,width=5,edge_color=edgeColorList,edgelist=edgeList,edge_cmap=plt.cm.Blues_r)
    plt.savefig(filename)

# %%
def runProgram():
    minWeight = 5

    G = createGridGraph(25)
    randomizeWeights(G,minWeight=95,maxWeight=105)
    correctWeightError(G)

    for a in range(20):
        print(a)
        for x in range(100):
        #    print(str(a) + "-" + str(x))
            path = getPath(G)
            
            adjustWeights(G,path=path,minWeight=minWeight,weightAdjust=.7)
            
        correctWeightError(G)
        base = r"C:\Users\Joe\Documents\Joe\Google Drive\Coding\ipython\Highways\testing_folder\joe_"
        filename = base + str(a) + ".png"
        saveImage(G,filename)

# %%
import cProfile
cProfile.run("runProgram()")
#runProgram()
# Out:
# 0.027427154781216812
# 0
# -15.837026383527155
# performing error correct
# performing error correct
# 1
# -11.219679837888446
# performing error correct
# performing error correct
# 2
# -9.472609616171297
# performing error correct
# performing error correct
# 3
# -8.85061820920524
# performing error correct
# performing error correct
# 4
# -9.47634784342002
# performing error correct
# performing error correct
# 5
# -8.54847797198164
# performing error correct
# performing error correct
# 6
# -7.949643583077571
# performing error correct
# performing error correct
# 7
# -8.431567375510337
# performing error correct
# performing error correct
# 8
# -8.490112461307557
# performing error correct
# performing error correct
# 9
# -7.74977507277159
# performing error correct
# performing error correct
# 10
# -7.801778963447687
# performing error correct
# performing error correct
# 11
# -7.781139360075468
# performing error correct
# performing error correct
# 12
# -7.271865130814852
# performing error correct
# performing error correct
# 13
# -8.15597180182164
# performing error correct
# performing error correct
# 14
# -7.744139168601953
# performing error correct
# performing error correct
# 15
# -7.021512665503009
# performing error correct
# performing error correct
# 16
# -6.959611165173956
# performing error correct
# performing error correct
# 17
# -7.376325182419011
# performing error correct
# performing error correct
# 18
# -7.667070559283566
# performing error correct
# performing error correct
# 19
# -7.0157392232469045
# performing error correct
# performing error correct
#          36329556 function calls (36284402 primitive calls) in 49.249 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1092    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap>:996(_handle_fromlist)
#         1    0.001    0.001    0.006    0.006 <ipython-input-11-7086d19f7552>:1(randomizeWeights)
#        20    0.003    0.000   40.721    2.036 <ipython-input-12-d5cace59b235>:1(saveImage)
#         1    0.016    0.016   49.248   49.248 <ipython-input-16-1e02f8532f45>:2(runProgram)
#        21    0.068    0.003    0.166    0.008 <ipython-input-23-c6ba5ef3e7c1>:1(correctWeightError)
#         1    0.001    0.001    0.015    0.015 <ipython-input-3-d43b0dc2ce37>:1(createGridGraph)
#      4002    0.017    0.000    0.115    0.000 <ipython-input-4-5f847ce89fe0>:1(getRandomNode)
#      2000    0.005    0.000    0.120    0.000 <ipython-input-5-ad3373eb2573>:1(getRandomSourceTarget)
#      2000    0.027    0.000    8.135    0.004 <ipython-input-6-e58fa7b795a4>:1(getPath)
#      2000    0.103    0.000    0.164    0.000 <ipython-input-7-dcd646e384c2>:1(adjustWeights)
#         1    0.000    0.000   49.249   49.249 <string>:1(<module>)
#       156    0.001    0.000    0.008    0.000 __init__.py:280(dumps)
#      7004    0.006    0.000    0.013    0.000 __init__.py:303(report)
#      7004    0.007    0.000    0.007    0.000 __init__.py:335(ge)
#     81598    0.088    0.000    0.088    0.000 __init__.py:871(__getitem__)
#        60    0.000    0.000    0.000    0.000 _base.py:1010(get_aspect)
#        60    0.001    0.000    0.007    0.000 _base.py:1145(apply_aspect)
#        20    0.001    0.000    0.085    0.004 _base.py:1460(add_collection)
#        40    0.000    0.000    0.003    0.000 _base.py:1649(update_datalim)
#        20    0.000    0.000    0.000    0.000 _base.py:1686(_process_unit_info)
#        20    0.001    0.000    0.021    0.001 _base.py:1917(autoscale_view)
#        20    0.000    0.000    0.000    0.000 _base.py:1939(<listcomp>)
#        20    0.000    0.000    0.000    0.000 _base.py:1941(<listcomp>)
#        20    0.000    0.000    0.000    0.000 _base.py:1965(<listcomp>)
#        20    0.000    0.000    0.001    0.000 _base.py:1967(<listcomp>)
#        60    0.022    0.000   38.522    0.642 _base.py:1989(draw)
#        20    0.001    0.000    0.001    0.000 _base.py:2040(<listcomp>)
#        40    0.003    0.000    0.004    0.000 _base.py:2042(<listcomp>)
#        60    0.000    0.000    0.000    0.000 _base.py:2048(<listcomp>)
#        20    0.000    0.000    0.000    0.000 _base.py:2440(xaxis_inverted)
#        20    0.000    0.000    0.000    0.000 _base.py:2445(get_xbound)
#        20    0.000    0.000    0.013    0.001 _base.py:2458(set_xbound)
#        60    0.000    0.000    0.000    0.000 _base.py:2485(get_xlim)
#        20    0.000    0.000    0.013    0.001 _base.py:2491(set_xlim)
#        60    0.000    0.000    0.000    0.000 _base.py:2583(get_xscale)
#        20    0.000    0.000    0.000    0.000 _base.py:2689(yaxis_inverted)
#        20    0.000    0.000    0.000    0.000 _base.py:2694(get_ybound)
#        20    0.000    0.000    0.002    0.000 _base.py:2705(set_ybound)
#        60    0.000    0.000    0.000    0.000 _base.py:2732(get_ylim)
#        20    0.000    0.000    0.002    0.000 _base.py:2738(set_ylim)
#        60    0.000    0.000    0.000    0.000 _base.py:2831(get_yscale)
#        60    0.000    0.000    0.002    0.000 _base.py:713(get_position)
#        60    0.001    0.000    0.003    0.000 _base.py:720(set_position)
#        60    0.000    0.000    0.000    0.000 _base.py:767(get_axes_locator)
#        20    0.000    0.000    0.000    0.000 _base.py:773(_set_artist_props)
#      4204    0.002    0.000    0.014    0.000 _methods.py:25(_amax)
#      3964    0.002    0.000    0.024    0.000 _methods.py:28(_amin)
#       260    0.000    0.000    0.002    0.000 _methods.py:37(_any)
#     30200    0.014    0.000    0.129    0.000 _methods.py:40(_all)
#       240    0.001    0.000    0.001    0.000 _methods.py:43(_count_reduce_items)
#       240    0.002    0.000    0.006    0.000 _methods.py:53(_mean)
#        60    0.000    0.000    0.000    0.000 _pylab_helpers.py:116(get_active)
#     12212    0.010    0.000    0.010    0.000 _weakrefset.py:16(__init__)
#     12212    0.012    0.000    0.015    0.000 _weakrefset.py:20(__enter__)
#     12212    0.020    0.000    0.028    0.000 _weakrefset.py:26(__exit__)
#        40    0.002    0.000    0.032    0.001 arrayprint.py:237(_array2string)
#        40    0.000    0.000    0.000    0.000 arrayprint.py:34(product)
#        40    0.001    0.000    0.033    0.001 arrayprint.py:340(array2string)
#       160    0.000    0.000    0.000    0.000 arrayprint.py:450(_extendLine)
#     80/40    0.001    0.000    0.007    0.000 arrayprint.py:458(_formatArray)
#       120    0.000    0.000    0.020    0.000 arrayprint.py:529(__init__)
#       120    0.011    0.000    0.020    0.000 arrayprint.py:543(fillFormat)
#        80    0.001    0.000    0.001    0.000 arrayprint.py:575(<listcomp>)
#       160    0.002    0.000    0.005    0.000 arrayprint.py:594(__call__)
#       160    0.001    0.000    0.001    0.000 arrayprint.py:628(_digits)
#        40    0.001    0.000    0.002    0.000 arrayprint.py:635(__init__)
#       120    0.000    0.000    0.000    0.000 arrayprint.py:657(__init__)
#        40    0.000    0.000    0.000    0.000 arrayprint.py:685(__init__)
#        40    0.000    0.000    0.013    0.000 arrayprint.py:696(__init__)
#        40    0.000    0.000    0.000    0.000 arrayprint.py:712(__init__)
#        40    0.000    0.000    0.000    0.000 arrayprint.py:740(__init__)
#      4230    0.025    0.000    0.036    0.000 artist.py:148(have_units)
#      5360    0.005    0.000    0.007    0.000 artist.py:155(convert_xunits)
#      5360    0.004    0.000    0.005    0.000 artist.py:165(convert_yunits)
#        20    0.000    0.000    0.000    0.000 artist.py:174(set_axes)
#       300    0.001    0.000    0.001    0.000 artist.py:235(pchanged)
#        20    0.000    0.000    0.000    0.000 artist.py:243(is_transform_set)
#        20    0.000    0.000    0.000    0.000 artist.py:250(set_transform)
#      8470    0.019    0.000    0.025    0.000 artist.py:261(get_transform)
#      9330    0.013    0.000    0.018    0.000 artist.py:41(before)
#      7470    0.003    0.000    0.003    0.000 artist.py:430(get_gid)
#      6510    0.021    0.000    0.046    0.000 artist.py:444(get_snap)
#      6510    0.003    0.000    0.003    0.000 artist.py:477(get_sketch_params)
#      9330    0.021    0.000    0.042    0.000 artist.py:48(after)
#      7470    0.003    0.000    0.003    0.000 artist.py:531(get_path_effects)
#        20    0.000    0.000    0.000    0.000 artist.py:541(set_figure)
#        20    0.000    0.000    0.008    0.000 artist.py:560(set_clip_path)
#   9330/60    0.054    0.000   38.590    0.643 artist.py:57(draw_wrapper)
#       960    0.000    0.000    0.000    0.000 artist.py:614(get_alpha)
#     11010    0.011    0.000    0.011    0.000 artist.py:621(get_visible)
#      3240    0.001    0.000    0.001    0.000 artist.py:625(get_animated)
#        20    0.000    0.000    0.000    0.000 artist.py:637(get_clip_path)
#      9390    0.020    0.000    0.027    0.000 artist.py:663(_set_gc_clip)
#     18660    0.019    0.000    0.019    0.000 artist.py:673(get_rasterized)
#     18660    0.007    0.000    0.007    0.000 artist.py:690(get_agg_filter)
#        20    0.000    0.000    0.000    0.000 artist.py:706(set_alpha)
#        20    0.000    0.000    0.000    0.000 artist.py:745(update)
#        20    0.000    0.000    0.000    0.000 artist.py:764(get_label)
#        40    0.000    0.000    0.000    0.000 artist.py:770(set_label)
#        60    0.000    0.000    0.000    0.000 artist.py:782(get_zorder)
#       160    0.000    0.000    0.001    0.000 artist.py:788(set_zorder)
#        20    0.000    0.000    0.000    0.000 artist.py:79(__init__)
#        39    0.000    0.000    0.000    0.000 attrsettr.py:35(__getattr__)
#       120    0.004    0.000    0.435    0.004 axis.py:1054(_get_tick_bboxes)
#       120    0.006    0.000    2.122    0.018 axis.py:1106(draw)
#        40    0.000    0.000    0.000    0.000 axis.py:1278(get_major_locator)
#       120    0.001    0.000    0.001    0.000 axis.py:1294(get_major_ticks)
#       120    0.000    0.000    0.000    0.000 axis.py:1317(get_minor_ticks)
#        20    0.000    0.000    0.000    0.000 axis.py:1382(update_units)
#      8480    0.011    0.000    0.011    0.000 axis.py:1438(have_units)
#        80    0.000    0.000    0.001    0.000 axis.py:1441(convert_units)
#       120    0.001    0.000    0.030    0.000 axis.py:1698(_get_pixel_distance_along_axis)
#        60    0.001    0.000    0.017    0.000 axis.py:1746(_update_label_position)
#        60    0.001    0.000    0.016    0.000 axis.py:1773(_update_offset_text_position)
#       180    0.000    0.000    0.001    0.000 axis.py:1876(get_view_interval)
#        20    0.000    0.000    0.000    0.000 axis.py:1901(get_minpos)
#       120    0.001    0.000    0.024    0.000 axis.py:2002(_get_pixel_distance_along_axis)
#        60    0.001    0.000    0.023    0.000 axis.py:2046(_update_label_position)
#        60    0.001    0.000    0.001    0.000 axis.py:2074(_update_offset_text_position)
#       180    0.000    0.000    0.001    0.000 axis.py:2181(get_view_interval)
#        20    0.000    0.000    0.000    0.000 axis.py:2206(get_minpos)
#       960    0.001    0.000    0.001    0.000 axis.py:228(get_loc)
#       960    0.016    0.000    1.484    0.002 axis.py:232(draw)
#       960    0.001    0.000    0.001    0.000 axis.py:255(set_label1)
#       960    0.001    0.000    0.001    0.000 axis.py:264(set_label2)
#       480    0.003    0.000    0.005    0.000 axis.py:436(update_position)
#       480    0.002    0.000    0.004    0.000 axis.py:463(get_view_interval)
#       480    0.003    0.000    0.004    0.000 axis.py:575(update_position)
#       480    0.001    0.000    0.003    0.000 axis.py:601(get_view_interval)
#      2040    0.001    0.000    0.001    0.000 axis.py:694(get_scale)
#        40    0.000    0.000    0.000    0.000 axis.py:713(limit_range_for_scale)
#      1080    0.004    0.000    0.049    0.000 axis.py:897(iter_ticks)
#       120    0.002    0.000    0.013    0.000 axis.py:904(<listcomp>)
#       120    0.000    0.000    0.000    0.000 axis.py:910(<listcomp>)
#       120    0.008    0.000    0.130    0.001 axis.py:949(_update_ticks)
#       120    0.001    0.000    0.050    0.000 axis.py:957(<listcomp>)
#      1920    0.009    0.000    0.120    0.000 backend_agg.py:123(draw_markers)
#      4230    0.033    0.000   34.658    0.008 backend_agg.py:126(draw_path_collection)
#        40    0.001    0.000    0.001    0.000 backend_agg.py:129(_update_methods)
#       360    0.007    0.000    0.071    0.000 backend_agg.py:140(draw_path)
#       960    0.036    0.000    0.288    0.000 backend_agg.py:180(draw_text)
#      1024    0.009    0.000    0.127    0.000 backend_agg.py:208(get_text_width_height_descent)
#       960    0.001    0.000    0.001    0.000 backend_agg.py:261(get_canvas_width_height)
#      1984    0.020    0.000    0.087    0.000 backend_agg.py:265(_get_agg_font)
#      3840    0.006    0.000    0.013    0.000 backend_agg.py:291(points_to_pixels)
#        20    0.000    0.000    0.004    0.000 backend_agg.py:315(clear)
#        60    0.000    0.000    0.000    0.000 backend_agg.py:318(option_image_nocomposite)
#        60    0.001    0.000   38.633    0.644 backend_agg.py:458(draw)
#        80    0.001    0.000    0.042    0.001 backend_agg.py:473(get_renderer)
#        20    0.001    0.000   14.146    0.707 backend_agg.py:520(print_png)
#      1984    0.007    0.000    0.008    0.000 backend_agg.py:53(get_hinting_flag)
#        40    0.002    0.000    0.034    0.001 backend_agg.py:85(__init__)
#      4200    0.003    0.000    0.003    0.000 backend_bases.py:1017(set_joinstyle)
#      4200    0.003    0.000    0.003    0.000 backend_bases.py:1026(set_linewidth)
#       360    0.001    0.000    0.001    0.000 backend_bases.py:1032(set_linestyle)
#      1320    0.001    0.000    0.001    0.000 backend_bases.py:1054(set_url)
#      8430    0.004    0.000    0.004    0.000 backend_bases.py:1066(set_snap)
#      7470    0.003    0.000    0.003    0.000 backend_bases.py:1091(get_hatch_path)
#      7470    0.002    0.000    0.002    0.000 backend_bases.py:1099(get_sketch_params)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:1317(__init__)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:1342(__init__)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:1684(is_saving)
#        60    0.000    0.000    0.001    0.000 backend_bases.py:1787(draw_event)
#        20    0.000    0.000    0.000    0.000 backend_bases.py:2041(_get_output_canvas)
#        20    0.001    0.000   14.274    0.714 backend_bases.py:2063(print_figure)
#        40    0.000    0.000    0.001    0.000 backend_bases.py:210(__init__)
#      8670    0.002    0.000    0.002    0.000 backend_bases.py:215(open_group)
#      8670    0.002    0.000    0.002    0.000 backend_bases.py:223(close_group)
#       960    0.000    0.000    0.000    0.000 backend_bases.py:683(flipy)
#      9390    0.020    0.000    0.056    0.000 backend_bases.py:704(new_gc)
#      9390    0.036    0.000    0.036    0.000 backend_bases.py:774(__init__)
#      9390    0.002    0.000    0.002    0.000 backend_bases.py:813(restore)
#      7470    0.004    0.000    0.004    0.000 backend_bases.py:844(get_clip_path)
#      7470    0.005    0.000    0.005    0.000 backend_bases.py:913(get_snap)
#      5160    0.006    0.000    0.082    0.000 backend_bases.py:926(set_alpha)
#      2280    0.001    0.000    0.001    0.000 backend_bases.py:942(set_antialiased)
#      4200    0.002    0.000    0.002    0.000 backend_bases.py:953(set_capstyle)
#      4230    0.003    0.000    0.003    0.000 backend_bases.py:962(set_clip_rectangle)
#      9390    0.005    0.000    0.005    0.000 backend_bases.py:968(set_clip_path)
#       360    0.000    0.000    0.000    0.000 backend_bases.py:976(set_dashes)
#     10320    0.014    0.000    0.091    0.000 backend_bases.py:994(set_foreground)
#        40    0.000    0.000   25.387    0.635 backend_qt5agg.py:140(draw)
#        20    0.000    0.000   26.747    1.337 backend_qt5agg.py:160(print_figure)
#       160    0.001    0.000    0.001    0.000 cbook.py:1284(__init__)
#       512    0.009    0.000    0.009    0.000 cbook.py:1289(__setitem__)
#        80    0.000    0.000    0.000    0.000 cbook.py:1665(clean)
#        80    0.000    0.000    0.000    0.000 cbook.py:1670(<listcomp>)
#        80    0.000    0.000    0.001    0.000 cbook.py:1733(get_siblings)
#        80    0.000    0.000    0.000    0.000 cbook.py:1740(<listcomp>)
#      1472    0.005    0.000    0.008    0.000 cbook.py:2158(is_math_text)
#        80    0.000    0.000    0.000    0.000 cbook.py:2334(_putmask)
#        20    0.000    0.000    0.000    0.000 cbook.py:475(__init__)
#       180    0.000    0.000    0.000    0.000 cbook.py:529(process)
#     26640    0.026    0.000    0.049    0.000 cbook.py:672(iterable)
#     71660    0.134    0.000    0.183    0.000 cbook.py:681(is_string_like)
#        20    0.000    0.000    0.000    0.000 cbook.py:735(is_numlike)
#         1    0.000    0.000    0.000    0.000 classic.py:311(empty_graph)
#         1    0.000    0.000    0.008    0.008 classic.py:359(grid_2d_graph)
#       626    0.000    0.000    0.000    0.000 classic.py:369(<genexpr>)
#       601    0.000    0.000    0.000    0.000 classic.py:370(<genexpr>)
#       601    0.000    0.000    0.000    0.000 classic.py:371(<genexpr>)
#        60    0.000    0.000    0.000    0.000 cm.py:134(get_cmap)
#        20    0.000    0.000    0.001    0.000 cm.py:173(__init__)
#        20    0.000    0.000    0.012    0.001 cm.py:207(to_rgba)
#        20    0.000    0.000    0.000    0.000 cm.py:266(set_array)
#        20    0.000    0.000    0.000    0.000 cm.py:301(set_cmap)
#        20    0.000    0.000    0.006    0.000 cm.py:318(autoscale)
#      4230    0.006    0.000    0.006    0.000 cm.py:345(check_update)
#        40    0.000    0.000    0.000    0.000 cm.py:355(changed)
#        20    0.058    0.003    0.532    0.027 collections.py:1087(set_segments)
#        20    0.039    0.002    0.410    0.020 collections.py:1099(<listcomp>)
#        20    0.000    0.000    0.000    0.000 collections.py:138(_get_value)
#        20    0.000    0.000    0.000    0.000 collections.py:153(_get_bool)
#      4250    0.003    0.000    0.003    0.000 collections.py:163(get_paths)
#      8480    0.005    0.000    0.005    0.000 collections.py:169(get_transforms)
#      4250    0.010    0.000    0.012    0.000 collections.py:172(get_offset_transform)
#        20    0.001    0.000    0.074    0.004 collections.py:179(get_datalim)
#      4230    0.084    0.000    0.224    0.000 collections.py:212(_prepare_points)
#      4230    0.201    0.000   36.154    0.009 collections.py:253(draw)
#        20    0.000    0.000    0.000    0.000 collections.py:325(set_pickradius)
#        20    0.000    0.000    0.000    0.000 collections.py:368(set_urls)
#        20    0.000    0.000    0.000    0.000 collections.py:377(set_hatch)
#        20    0.000    0.000    0.000    0.000 collections.py:438(set_offset_position)
#        20    0.000    0.000    0.001    0.000 collections.py:461(set_linewidth)
#        60    0.000    0.000    0.001    0.000 collections.py:481(set_linestyle)
#        20    0.000    0.000    0.000    0.000 collections.py:523(set_linestyles)
#        20    0.000    0.000    0.000    0.000 collections.py:531(set_antialiased)
#        20    0.000    0.000    0.000    0.000 collections.py:559(set_facecolor)
#      8460    0.004    0.000    0.004    0.000 collections.py:585(get_facecolor)
#      8460    0.137    0.000    0.137    0.000 collections.py:589(get_edgecolor)
#        20    0.000    0.000    0.026    0.001 collections.py:596(set_edgecolor)
#        20    0.001    0.000    0.012    0.001 collections.py:631(set_alpha)
#      4230    0.018    0.000    0.037    0.000 collections.py:664(update_scalarmappable)
#        20    0.001    0.000    0.030    0.002 collections.py:87(__init__)
#        20    0.001    0.000    0.564    0.028 collections.py:990(__init__)
#      9660    0.005    0.000    0.005    0.000 colors.py:265(to_rgb)
#     12020    0.050    0.000    0.130    0.000 colors.py:334(to_rgba)
#     11600    0.011    0.000    0.011    0.000 colors.py:353(<genexpr>)
#       100    0.002    0.000    0.038    0.000 colors.py:378(to_rgba_array)
#        20    0.002    0.000    0.005    0.000 colors.py:528(__call__)
#        20    0.000    0.000    0.000    0.000 colors.py:852(__init__)
#        20    0.000    0.000    0.003    0.000 colors.py:872(process_value)
#        20    0.001    0.000    0.004    0.000 colors.py:904(__call__)
#        20    0.000    0.000    0.005    0.000 colors.py:944(autoscale)
#        20    0.000    0.000    0.000    0.000 colors.py:951(autoscale_None)
#        20    0.000    0.000    0.000    0.000 core.py:1290(getmask)
#        40    0.000    0.000    0.000    0.000 core.py:1743(_check_mask_axis)
#        40    0.000    0.000    0.000    0.000 core.py:231(_recursive_extremum_fill_value)
#        20    0.000    0.000    0.000    0.000 core.py:242(minimum_fill_value)
#        20    0.000    0.000    0.000    0.000 core.py:2513(__get__)
#        20    0.000    0.000    0.001    0.000 core.py:2517(__call__)
#       120    0.002    0.000    0.008    0.000 core.py:2707(__new__)
#       220    0.002    0.000    0.003    0.000 core.py:2835(_update_from)
#       200    0.003    0.000    0.006    0.000 core.py:2861(__array_finalize__)
#        20    0.000    0.000    0.000    0.000 core.py:305(maximum_fill_value)
#       580    0.001    0.000    0.001    0.000 core.py:3225(__setattr__)
#        40    0.000    0.000    0.000    0.000 core.py:3327(_get_mask)
#       100    0.000    0.000    0.000    0.000 core.py:3445(_get_data)
#        60    0.000    0.000    0.000    0.000 core.py:3537(filled)
#        20    0.000    0.000    0.001    0.000 core.py:5349(min)
#        20    0.000    0.000    0.001    0.000 core.py:5448(max)
#      2920    0.006    0.000    0.012    0.000 core.py:553(filled)
#    114470    0.056    0.000    0.082    0.000 core.py:5954(isMaskedArray)
#        40    0.000    0.000    0.003    0.000 core.py:6045(array)
#        20    0.000    0.000    0.003    0.000 core.py:6206(min)
#        20    0.000    0.000    0.002    0.000 core.py:6216(max)
#        40    0.000    0.000    0.003    0.000 core.py:7264(asarray)
#        40    0.000    0.000    0.002    0.000 core.py:7312(asanyarray)
#        39    0.000    0.000    0.000    0.000 cp1252.py:11(encode)
#       156    0.001    0.000    0.001    0.000 encoder.py:121(__init__)
#       156    0.001    0.000    0.006    0.000 encoder.py:254(encode)
#       156    0.003    0.000    0.006    0.000 encoder.py:283(iterencode)
#      1092    0.001    0.000    0.003    0.000 encoder.py:42(encode_basestring)
#        78    0.000    0.000    0.000    0.000 encoder.py:52(replace)
#        60    0.012    0.000   38.589    0.643 figure.py:1004(draw)
#        60    0.000    0.000    0.000    0.000 figure.py:1082(<listcomp>)
#        20    0.000    0.000    0.000    0.000 figure.py:1232(gca)
#        20    0.000    0.000    0.000    0.000 figure.py:134(current_key_axes)
#        20    0.000    0.000   26.748    1.337 figure.py:1375(savefig)
#        60    0.000    0.000    0.001    0.000 figure.py:390(_get_axes)
#      2340    0.001    0.000    0.001    0.000 figure.py:395(_get_dpi)
#        40    0.001    0.000    0.123    0.003 figure.py:398(_set_dpi)
#        60    0.000    0.000    0.000    0.000 figure.py:404(get_tight_layout)
#        20    0.000    0.000    0.000    0.000 figure.py:537(set_canvas)
#        20    0.000    0.000    0.000    0.000 figure.py:697(get_edgecolor)
#        20    0.000    0.000    0.000    0.000 figure.py:701(get_facecolor)
#        20    0.000    0.000    0.000    0.000 figure.py:717(get_frameon)
#        40    0.000    0.000    0.001    0.000 figure.py:721(set_edgecolor)
#        40    0.000    0.000    0.002    0.000 figure.py:729(set_facecolor)
#        60    0.000    0.000    0.001    0.000 figure.py:73(as_list)
#        40    0.000    0.000    0.000    0.000 figure.py:761(set_frameon)
#        60    0.000    0.000    0.000    0.000 figure.py:77(<listcomp>)
#        60    0.000    0.000    0.000    0.000 figure.py:79(<listcomp>)
#      5888    0.012    0.000    0.018    0.000 font_manager.py:1071(get_default_size)
#      3904    0.025    0.000    0.077    0.000 font_manager.py:701(__hash__)
#      3904    0.002    0.000    0.002    0.000 font_manager.py:720(get_family)
#      3904    0.002    0.000    0.002    0.000 font_manager.py:738(get_style)
#      3904    0.001    0.000    0.001    0.000 font_manager.py:748(get_variant)
#      3904    0.001    0.000    0.001    0.000 font_manager.py:757(get_weight)
#      3904    0.001    0.000    0.001    0.000 font_manager.py:768(get_stretch)
#      5888    0.034    0.000    0.055    0.000 font_manager.py:786(get_size_in_points)
#      3904    0.001    0.000    0.001    0.000 font_manager.py:795(get_file)
#       120    0.000    0.000    0.001    0.000 fromnumeric.py:1373(ravel)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:1676(clip)
#        60    0.000    0.000    0.006    0.000 fromnumeric.py:1866(alltrue)
#       180    0.001    0.000    0.003    0.000 fromnumeric.py:1883(any)
#        40    0.000    0.000    0.001    0.000 fromnumeric.py:1964(all)
#       120    0.000    0.000    0.002    0.000 fromnumeric.py:2126(ptp)
#      2920    0.003    0.000    0.011    0.000 fromnumeric.py:2171(amax)
#      2920    0.003    0.000    0.021    0.000 fromnumeric.py:2262(amin)
#      2160    0.002    0.000    0.012    0.000 fromnumeric.py:2767(round_)
#       240    0.001    0.000    0.006    0.000 fromnumeric.py:2785(mean)
#        40    0.000    0.000    0.000    0.000 fromnumeric.py:56(take)
#         1    0.000    0.000    0.000    0.000 function.py:303(set_node_attributes)
#        21    0.003    0.000    0.010    0.000 function.py:336(get_node_attributes)
#     13146    0.006    0.000    0.006    0.000 function.py:358(<genexpr>)
#        24    0.035    0.001    0.045    0.002 function.py:361(set_edge_attributes)
#        42    0.014    0.000    0.104    0.002 function.py:405(get_edge_attributes)
#     50442    0.034    0.000    0.034    0.000 function.py:433(<genexpr>)
#      2000    0.201    0.000    7.988    0.004 generic.py:41(shortest_path)
#        20    0.000    0.000    0.000    0.000 genericpath.py:111(_splitext)
#        44    0.008    0.000    0.059    0.001 graph.py:1085(edges)
#     52844    0.048    0.000    0.051    0.000 graph.py:1133(edges_iter)
#    150064    0.038    0.000    0.038    0.000 graph.py:1209(get_edge_data)
#      2068    0.001    0.000    0.001    0.000 graph.py:1444(is_multigraph)
#      2021    0.000    0.000    0.000    0.000 graph.py:1448(is_directed)
#         1    0.000    0.000    0.000    0.000 graph.py:257(__init__)
#         2    0.000    0.000    0.000    0.000 graph.py:309(name)
#     28800    0.008    0.000    0.008    0.000 graph.py:378(__getitem__)
#         2    0.001    0.001    0.001    0.001 graph.py:465(add_nodes_from)
#      4003    0.003    0.000    0.005    0.000 graph.py:609(nodes_iter)
#      4003    0.069    0.000    0.074    0.000 graph.py:644(nodes)
#         2    0.004    0.002    0.006    0.003 graph.py:802(add_edges_from)
#     42630    0.023    0.000    0.023    0.000 graph.py:979(has_edge)
#        39    0.000    0.000    0.000    0.000 hmac.py:108(_current)
#        39    0.000    0.000    0.000    0.000 hmac.py:127(hexdigest)
#       156    0.000    0.000    0.000    0.000 hmac.py:90(update)
#        39    0.000    0.000    0.000    0.000 hmac.py:95(copy)
#       203    0.000    0.000    0.001    0.000 iostream.py:102(_check_mp_mode)
#        39    0.000    0.000    0.002    0.000 iostream.py:123(_flush_from_subprocesses)
#        39    0.001    0.000    0.040    0.001 iostream.py:151(flush)
#       164    0.001    0.000    0.042    0.000 iostream.py:207(write)
#        39    0.000    0.000    0.000    0.000 iostream.py:238(_flush_buffer)
#        39    0.000    0.000    0.000    0.000 iostream.py:247(_new_buffer)
#       242    0.000    0.000    0.001    0.000 iostream.py:93(_is_master_process)
#        39    0.000    0.000    0.000    0.000 iostream.py:96(_is_master_thread)
#       156    0.001    0.000    0.008    0.000 jsonapi.py:31(dumps)
#        39    0.000    0.000    0.000    0.000 jsonutil.py:75(date_default)
#        60    0.000    0.000    0.000    0.000 linalg.py:101(get_linalg_error_extobj)
#        60    0.000    0.000    0.000    0.000 linalg.py:106(_makearray)
#       120    0.000    0.000    0.000    0.000 linalg.py:111(isComplexType)
#        60    0.000    0.000    0.000    0.000 linalg.py:124(_realType)
#        60    0.000    0.000    0.000    0.000 linalg.py:139(_commonType)
#        60    0.000    0.000    0.000    0.000 linalg.py:198(_assertRankAtLeast2)
#        60    0.000    0.000    0.000    0.000 linalg.py:209(_assertNdSquareness)
#        60    0.002    0.000    0.004    0.000 linalg.py:458(inv)
#         2    0.000    0.000    0.000    0.000 linecache.py:15(getline)
#         2    0.000    0.000    0.000    0.000 linecache.py:37(getlines)
#       960    0.001    0.000    0.001    0.000 lines.py:1039(set_xdata)
#       960    0.001    0.000    0.001    0.000 lines.py:1048(set_ydata)
#      3840    0.011    0.000    0.035    0.000 lines.py:1159(_get_rgba_face)
#      1920    0.004    0.000    0.014    0.000 lines.py:1167(_get_rgba_ln_color)
#      1920    0.002    0.000    0.002    0.000 lines.py:1315(is_dashed)
#      1920    0.002    0.000    0.003    0.000 lines.py:446(get_fillstyle)
#      1920    0.001    0.000    0.001    0.000 lines.py:515(get_markevery)
#      1920    0.056    0.000    0.167    0.000 lines.py:569(recache)
#      1920    0.007    0.000    0.064    0.000 lines.py:623(_transform_path)
#      1920    0.002    0.000    0.066    0.000 lines.py:636(_get_transformed_path)
#      1920    0.106    0.000    0.943    0.000 lines.py:661(draw)
#      1920    0.005    0.000    0.007    0.000 lines.py:796(get_markeredgecolor)
#      3840    0.008    0.000    0.014    0.000 lines.py:811(_get_markerfacecolor)
#      1920    0.005    0.000    0.006    0.000 markers.py:194(__bool__)
#      1920    0.001    0.000    0.001    0.000 markers.py:200(is_filled)
#      1920    0.001    0.000    0.001    0.000 markers.py:203(get_fillstyle)
#      1920    0.001    0.000    0.001    0.000 markers.py:220(get_joinstyle)
#      1920    0.001    0.000    0.001    0.000 markers.py:223(get_capstyle)
#      3840    0.001    0.000    0.001    0.000 markers.py:226(get_marker)
#      1920    0.000    0.000    0.000    0.000 markers.py:252(get_path)
#      1920    0.003    0.000    0.039    0.000 markers.py:255(get_transform)
#      1920    0.001    0.000    0.001    0.000 markers.py:258(get_alt_path)
#      1920    0.001    0.000    0.001    0.000 markers.py:264(get_snap_threshold)
#        80    0.000    0.000    0.001    0.000 mathtext.py:2957(__init__)
#        20    0.000    0.000    0.000    0.000 ntpath.py:220(splitext)
#        40    0.000    0.000    0.033    0.001 numeric.py:1737(array_str)
#       692    0.005    0.000    0.016    0.000 numeric.py:2181(identity)
#       800    0.003    0.000    0.007    0.000 numeric.py:2473(seterr)
#       800    0.003    0.000    0.003    0.000 numeric.py:2573(geterr)
#       400    0.001    0.000    0.001    0.000 numeric.py:2860(__init__)
#       400    0.001    0.000    0.005    0.000 numeric.py:2864(__enter__)
#       400    0.001    0.000    0.004    0.000 numeric.py:2869(__exit__)
#     60652    0.064    0.000    0.207    0.000 numeric.py:406(asarray)
#     10370    0.020    0.000    0.049    0.000 numeric.py:476(asanyarray)
#        40    0.000    0.000    0.000    0.000 numerictypes.py:603(obj2sctype)
#        40    0.000    0.000    0.000    0.000 numerictypes.py:774(__getitem__)
#        20    0.004    0.000    0.986    0.049 nx_pylab.py:403(draw_networkx_edges)
#        20    0.013    0.001    0.013    0.001 nx_pylab.py:513(<listcomp>)
#        20    0.011    0.001    0.082    0.004 nx_pylab.py:523(<listcomp>)
#        20    0.017    0.001    0.098    0.005 nx_pylab.py:529(<listcomp>)
#        20    0.011    0.001    0.056    0.003 nx_pylab.py:532(<listcomp>)
#       380    0.002    0.000    0.047    0.000 patches.py:185(get_transform)
#       240    0.001    0.000    0.003    0.000 patches.py:199(get_patch_transform)
#        20    0.000    0.000    0.000    0.000 patches.py:217(get_edgecolor)
#        20    0.000    0.000    0.000    0.000 patches.py:224(get_facecolor)
#        40    0.000    0.000    0.001    0.000 patches.py:260(set_edgecolor)
#        40    0.000    0.000    0.002    0.000 patches.py:275(set_facecolor)
#       360    0.010    0.000    0.177    0.000 patches.py:434(draw)
#       120    0.000    0.000    0.000    0.000 patches.py:603(get_path)
#       140    0.004    0.000    0.037    0.000 patches.py:609(_update_patch_transform)
#       140    0.000    0.000    0.037    0.000 patches.py:625(get_patch_transform)
#     30040    0.094    0.000    0.526    0.000 path.py:103(__init__)
#     30040    0.134    0.000    0.330    0.000 path.py:199(_update_values)
#   5112800    1.307    0.000    1.307    0.000 path.py:207(vertices)
#   5106400    0.731    0.000    0.731    0.000 path.py:221(codes)
#   5104240    0.644    0.000    0.644    0.000 path.py:240(simplify_threshold)
#   5104240    0.669    0.000    0.669    0.000 path.py:259(should_simplify)
#       120    0.000    0.000    0.000    0.000 path.py:595(unit_rectangle)
#        20    0.002    0.000    0.067    0.003 path.py:937(get_path_collection_extents)
#        39    0.000    0.000    0.002    0.000 poll.py:77(poll)
#        39    0.000    0.000    0.000    0.000 py3compat.py:19(encode)
#        40    0.000    0.000    0.000    0.000 pyplot.py:455(gcf)
#        20    0.000    0.000    0.000    0.000 pyplot.py:481(get_current_fig_manager)
#        20    0.000    0.000   12.914    0.646 pyplot.py:551(draw)
#        20    0.000    0.000   39.662    1.983 pyplot.py:574(savefig)
#        20    0.000    0.000    0.001    0.000 pyplot.py:810(gca)
#      4002    0.009    0.000    0.014    0.000 random.py:220(_randbelow)
#      4002    0.009    0.000    0.024    0.000 random.py:250(choice)
#      1200    0.001    0.000    0.001    0.000 random.py:342(uniform)
#        40    0.000    0.000    0.000    0.000 scale.py:48(limit_range_for_scale)
#        39    0.000    0.000    0.000    0.000 session.py:206(msg_header)
#        39    0.000    0.000    0.000    0.000 session.py:211(extract_header)
#        39    0.000    0.000    0.002    0.000 session.py:452(msg_id)
#        39    0.000    0.000    0.003    0.000 session.py:504(msg_header)
#        39    0.000    0.000    0.003    0.000 session.py:507(msg)
#        39    0.000    0.000    0.002    0.000 session.py:526(sign)
#        39    0.001    0.000    0.012    0.000 session.py:541(serialize)
#        39    0.001    0.000    0.035    0.001 session.py:600(send)
#        39    0.000    0.000    0.000    0.000 session.py:667(<listcomp>)
#       156    0.000    0.000    0.009    0.000 session.py:94(<lambda>)
#        80    0.000    0.000    0.003    0.000 shape_base.py:180(vstack)
#        80    0.000    0.000    0.002    0.000 shape_base.py:230(<listcomp>)
#       240    0.001    0.000    0.002    0.000 shape_base.py:61(atleast_2d)
#     12272    0.014    0.000    0.017    0.000 six.py:577(itervalues)
#       320    0.001    0.000    0.001    0.000 six.py:580(iteritems)
#        39    0.001    0.000    0.019    0.000 socket.py:289(send_multipart)
#       240    0.001    0.000    0.003    0.000 spines.py:132(get_patch_transform)
#       240    0.000    0.000    0.000    0.000 spines.py:139(get_path)
#       240    0.003    0.000    0.004    0.000 spines.py:185(_adjust_location)
#       240    0.001    0.000    0.084    0.000 spines.py:270(draw)
#      2040    0.001    0.000    0.001    0.000 text.py:1020(set_text)
#      1472    0.005    0.000    0.019    0.000 text.py:1030(is_math_text)
#      1472    0.002    0.000    0.005    0.000 text.py:254(get_rotation)
#       512    0.000    0.000    0.000    0.000 text.py:271(get_rotation_mode)
#      1920    0.054    0.000    0.356    0.000 text.py:287(_get_layout)
#      1472    0.003    0.000    0.003    0.000 text.py:46(get_rotation)
#      1380    0.046    0.000    0.486    0.000 text.py:581(draw)
#       960    0.000    0.000    0.000    0.000 text.py:647(get_color)
#      3120    0.011    0.000    0.017    0.000 text.py:726(get_position)
#      1920    0.012    0.000    0.068    0.000 text.py:732(get_prop_tup)
#      4772    0.002    0.000    0.002    0.000 text.py:748(get_text)
#       960    0.014    0.000    0.430    0.000 text.py:763(get_window_extent)
#       240    0.001    0.000    0.001    0.000 text.py:970(set_position)
#       720    0.000    0.000    0.000    0.000 text.py:979(set_x)
#       720    0.000    0.000    0.000    0.000 text.py:987(set_y)
#        40    0.001    0.000    0.001    0.000 textpath.py:36(__init__)
#        39    0.000    0.000    0.000    0.000 threading.py:1099(ident)
#        39    0.000    0.000    0.000    0.000 threading.py:1233(current_thread)
#       120    0.000    0.000    0.000    0.000 ticker.py:1060(__call__)
#       120    0.000    0.000    0.000    0.000 ticker.py:1063(tick_values)
#       160    0.002    0.000    0.002    0.000 ticker.py:1225(scale_range)
#       160    0.005    0.000    0.008    0.000 ticker.py:1326(bin_boundaries)
#       120    0.001    0.000    0.010    0.000 ticker.py:1351(__call__)
#       120    0.001    0.000    0.009    0.000 ticker.py:1355(tick_values)
#        40    0.000    0.000    0.002    0.000 ticker.py:1368(view_limits)
#       120    0.000    0.000    0.000    0.000 ticker.py:227(set_locs)
#      1080    0.002    0.000    0.005    0.000 ticker.py:434(fix_minus)
#       960    0.002    0.000    0.011    0.000 ticker.py:441(__call__)
#       120    0.000    0.000    0.001    0.000 ticker.py:483(get_offset)
#       120    0.001    0.000    0.021    0.000 ticker.py:514(set_locs)
#       120    0.002    0.000    0.009    0.000 ticker.py:525(_set_offset)
#       120    0.001    0.000    0.001    0.000 ticker.py:546(_set_orderOfMagnitude)
#       120    0.004    0.000    0.010    0.000 ticker.py:572(_set_format)
#       960    0.005    0.000    0.005    0.000 ticker.py:601(pprint_val)
#       120    0.000    0.000    0.000    0.000 ticker.py:938(raise_if_exceeds)
#       507    0.000    0.000    0.000    0.000 traitlets.py:499(get)
#       507    0.001    0.000    0.001    0.000 traitlets.py:518(__get__)
#      6600    0.005    0.000    0.005    0.000 transforms.py:1003(get_points)
#        60    0.001    0.000    0.002    0.000 transforms.py:1021(set)
#        20    0.000    0.000    0.000    0.000 transforms.py:1051(__init__)
#      4470    0.023    0.000    0.204    0.000 transforms.py:1071(get_points)
#       520    0.001    0.000    0.009    0.000 transforms.py:1132(__add__)
#      2972    0.008    0.000    0.194    0.000 transforms.py:126(invalidate)
#      5240    0.029    0.000    0.290    0.000 transforms.py:1274(transform)
#        40    0.000    0.000    0.002    0.000 transforms.py:1362(get_matrix)
# 15712/2972    0.060    0.000    0.186    0.000 transforms.py:137(_invalidate_internal)
#      2400    0.010    0.000    0.154    0.000 transforms.py:1370(transform_point)
#      2160    0.008    0.000    0.080    0.000 transforms.py:1405(transform_path_non_affine)
#      4250    0.006    0.000    0.148    0.000 transforms.py:1535(frozen)
#     10530    0.011    0.000    0.011    0.000 transforms.py:1573(_get_is_affine)
#     43802    0.053    0.000    0.330    0.000 transforms.py:1593(__init__)
#     12700    0.011    0.000    0.016    0.000 transforms.py:1597(__array__)
#        40    0.000    0.000    0.003    0.000 transforms.py:1609(__eq__)
#     11380    0.044    0.000    0.174    0.000 transforms.py:161(set_children)
#      6364    0.006    0.000    0.050    0.000 transforms.py:1614(transform)
#     12680    0.002    0.000    0.002    0.000 transforms.py:1640(get_affine)
#     25090    0.077    0.000    0.515    0.000 transforms.py:1666(frozen)
#      6364    0.014    0.000    0.044    0.000 transforms.py:1694(transform_affine)
#        80    0.000    0.000    0.001    0.000 transforms.py:1701(transform_point)
#       780    0.001    0.000    0.006    0.000 transforms.py:1722(inverted)
#     34922    0.055    0.000    0.351    0.000 transforms.py:1739(__init__)
#     44994    0.025    0.000    0.025    0.000 transforms.py:1784(get_matrix)
#        40    0.000    0.000    0.121    0.003 transforms.py:1830(clear)
#       652    0.008    0.000    0.029    0.000 transforms.py:1838(rotate)
#       652    0.001    0.000    0.031    0.000 transforms.py:1855(rotate_deg)
#       140    0.001    0.000    0.012    0.000 transforms.py:1875(rotate_deg_around)
#       280    0.001    0.000    0.008    0.000 transforms.py:1885(translate)
#      1960    0.010    0.000    0.093    0.000 transforms.py:1900(scale)
#        20    0.000    0.000    0.000    0.000 transforms.py:1966(frozen)
#      4250    0.002    0.000    0.002    0.000 transforms.py:1973(get_matrix)
#      1920    0.003    0.000    0.010    0.000 transforms.py:2058(_get_is_affine)
#      4080    0.005    0.000    0.016    0.000 transforms.py:2073(transform_non_affine)
#      4080    0.007    0.000    0.017    0.000 transforms.py:2104(get_affine)
#      4630    0.004    0.000    0.004    0.000 transforms.py:2174(get_matrix)
#       800    0.003    0.000    0.021    0.000 transforms.py:2215(__init__)
# 8500/4250    0.059    0.000    0.774    0.000 transforms.py:2236(frozen)
# 4980/4200    0.006    0.000    0.113    0.000 transforms.py:2244(_invalidate_internal)
#        40    0.000    0.000    0.000    0.000 transforms.py:2259(__eq__)
# 24440/14150    0.038    0.000    0.049    0.000 transforms.py:2275(_get_is_affine)
#      5240    0.016    0.000    0.217    0.000 transforms.py:2290(transform_affine)
#      5240    0.009    0.000    0.023    0.000 transforms.py:2294(transform_non_affine)
#       120    0.000    0.000    0.000    0.000 transforms.py:2304(transform_path_non_affine)
# 9040/5480    0.045    0.000    0.175    0.000 transforms.py:2314(get_affine)
#   520/260    0.002    0.000    0.022    0.000 transforms.py:2322(inverted)
#      8500    0.033    0.000    0.209    0.000 transforms.py:2338(__init__)
#      8500    0.023    0.000    0.105    0.000 transforms.py:2379(get_matrix)
#      9020    0.029    0.000    0.251    0.000 transforms.py:2390(composite_transform_factory)
#       140    0.001    0.000    0.004    0.000 transforms.py:2468(__init__)
# 10690/10650    0.007    0.000    0.011    0.000 transforms.py:2484(get_matrix)
#      4630    0.004    0.000    0.005    0.000 transforms.py:2542(get_matrix)
#      1920    0.002    0.000    0.003    0.000 transforms.py:2575(get_matrix)
#      1920    0.007    0.000    0.054    0.000 transforms.py:2601(__init__)
#      1920    0.012    0.000    0.123    0.000 transforms.py:2615(_revalidate)
#      1920    0.003    0.000    0.130    0.000 transforms.py:2626(get_transformed_points_and_affine)
#      1920    0.002    0.000    0.003    0.000 transforms.py:2653(get_affine)
#       240    0.002    0.000    0.003    0.000 transforms.py:2657(nonsingular)
#      1920    0.006    0.000    0.006    0.000 transforms.py:2702(interval_contains)
#        60    0.000    0.000    0.002    0.000 transforms.py:276(frozen)
#      4290    0.008    0.000    0.210    0.000 transforms.py:280(__array__)
#        60    0.000    0.000    0.000    0.000 transforms.py:290(_get_x0)
#       120    0.000    0.000    0.000    0.000 transforms.py:297(_get_y0)
#        60    0.000    0.000    0.001    0.000 transforms.py:347(_get_ymax)
#       860    0.003    0.000    0.003    0.000 transforms.py:365(_get_intervalx)
#       860    0.002    0.000    0.003    0.000 transforms.py:372(_get_intervaly)
#       320    0.003    0.000    0.007    0.000 transforms.py:400(_get_bounds)
#        20    0.000    0.000    0.002    0.000 transforms.py:515(transformed)
#        20    0.000    0.000    0.004    0.000 transforms.py:525(inverse_transformed)
#       960    0.014    0.000    0.032    0.000 transforms.py:688(translated)
#       220    0.009    0.000    0.051    0.000 transforms.py:717(union)
#      1952    0.013    0.000    0.044    0.000 transforms.py:774(__init__)
#        20    0.000    0.000    0.001    0.000 transforms.py:805(unit)
#       692    0.002    0.000    0.028    0.000 transforms.py:821(from_bounds)
#       892    0.005    0.000    0.035    0.000 transforms.py:831(from_extents)
#     48494    0.094    0.000    0.316    0.000 transforms.py:85(__init__)
#        40    0.000    0.000    0.001    0.000 transforms.py:883(update_from_path)
#        40    0.000    0.000    0.002    0.000 transforms.py:919(update_from_data_xy)
#        20    0.001    0.000    0.012    0.001 transforms.py:973(_set_intervalx)
#        20    0.000    0.000    0.000    0.000 transforms.py:978(_set_intervaly)
#        20    0.000    0.000    0.000    0.000 transforms.py:995(_get_minposx)
#        20    0.000    0.000    0.000    0.000 transforms.py:999(_get_minposy)
#       692    0.006    0.000    0.009    0.000 twodim_base.py:192(eye)
#   120/100    0.000    0.000    0.001    0.000 units.py:125(get_converter)
#        39    0.000    0.000    0.001    0.000 uuid.py:104(__init__)
#        39    0.000    0.000    0.000    0.000 uuid.py:223(__str__)
#        39    0.000    0.000    0.001    0.000 uuid.py:601(uuid4)
#         2    0.000    0.000    0.000    0.000 warnings.py:10(showwarning)
#         2    0.000    0.000    0.000    0.000 warnings.py:22(formatwarning)
#     48494    0.176    0.000    0.222    0.000 weakref.py:101(__init__)
#     20560    0.025    0.000    0.025    0.000 weakref.py:102(remove)
#     12212    0.006    0.000    0.006    0.000 weakref.py:116(_commit_removals)
#     20700    0.053    0.000    0.126    0.000 weakref.py:149(__setitem__)
#     24952    0.048    0.000    0.103    0.000 weakref.py:214(values)
#     48494    0.037    0.000    0.046    0.000 weakref.py:255(update)
#     20700    0.022    0.000    0.031    0.000 weakref.py:292(__new__)
#     20700    0.041    0.000    0.041    0.000 weakref.py:297(__init__)
#      2000    0.043    0.000    7.781    0.004 weighted.py:231(single_source_dijkstra)
#   4888400    1.357    0.000    1.932    0.000 weighted.py:292(<lambda>)
#      2000    4.881    0.002    7.738    0.004 weighted.py:299(_dijkstra)
#      2000    0.006    0.000    7.787    0.004 weighted.py:36(dijkstra_path)
#        40    0.026    0.001    0.026    0.001 {built-in method RendererAgg}
#     20739    0.009    0.000    0.009    0.000 {built-in method __new__ of type object at 0x000000006949BB40}
#        39    0.000    0.000    0.000    0.000 {built-in method _codecs.charmap_encode}
#        40    0.000    0.000    0.000    0.000 {built-in method _functools.reduce}
#    675656    0.495    0.000    0.495    0.000 {built-in method _heapq.heappop}
#    898233    0.244    0.000    0.244    0.000 {built-in method _heapq.heappush}
#        39    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#      6444    0.022    0.000    0.022    0.000 {built-in method affine_transform}
#        20    0.000    0.000    0.000    0.000 {built-in method buffer_rgba}
#      1221    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#      2320    0.004    0.000    0.015    0.000 {built-in method builtins.any}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       480    0.001    0.000    0.001    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000   49.249   49.249 {built-in method builtins.exec}
#     13279    0.004    0.000    0.004    0.000 {built-in method builtins.getattr}
#      9403    0.008    0.000    0.009    0.000 {built-in method builtins.hasattr}
# 7808/3904    0.009    0.000    0.083    0.000 {built-in method builtins.hash}
#     22620    0.005    0.000    0.005    0.000 {built-in method builtins.id}
#    258759    0.073    0.000    0.073    0.000 {built-in method builtins.isinstance}
#       620    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#     43235    0.028    0.000    0.028    0.000 {built-in method builtins.iter}
#    122665    0.022    0.000    0.022    0.000 {built-in method builtins.len}
#        39    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#      5607    0.003    0.000    0.003    0.000 {built-in method builtins.max}
#      3080    0.002    0.000    0.002    0.000 {built-in method builtins.min}
#    898233    0.120    0.000    0.120    0.000 {built-in method builtins.next}
#       120    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#        81    0.001    0.000    0.043    0.001 {built-in method builtins.print}
#        61    0.001    0.000    0.001    0.000 {built-in method builtins.sum}
#        20    0.004    0.000    0.004    0.000 {built-in method clear}
#      1920    0.102    0.000    0.112    0.000 {built-in method draw_markers}
#      4230   31.061    0.007   34.625    0.008 {built-in method draw_path_collection}
#       360    0.062    0.000    0.063    0.000 {built-in method draw_path}
#       960    0.080    0.000    0.081    0.000 {built-in method draw_text_image}
#        39    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#        20    0.052    0.003    0.064    0.003 {built-in method get_path_collection_extents}
#        20    0.017    0.001    0.017    0.001 {built-in method io.open}
#       480    0.000    0.000    0.000    0.000 {built-in method math.floor}
#       640    0.001    0.000    0.001    0.000 {built-in method math.log10}
#        39    0.000    0.000    0.000    0.000 {built-in method now}
#       281    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#        39    0.000    0.000    0.000    0.000 {built-in method nt.urandom}
#       160    0.001    0.000    0.001    0.000 {built-in method numpy.core.multiarray.arange}
#     77810    0.209    0.000    0.209    0.000 {built-in method numpy.core.multiarray.array}
#      2000    0.010    0.000    0.010    0.000 {built-in method numpy.core.multiarray.concatenate}
#        80    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.copyto}
#     20432    0.134    0.000    0.134    0.000 {built-in method numpy.core.multiarray.dot}
#        20    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.empty}
#      2268    0.004    0.000    0.004    0.000 {built-in method numpy.core.multiarray.zeros}
#      1600    0.001    0.000    0.001    0.000 {built-in method numpy.core.umath.geterrobj}
#       800    0.001    0.000    0.001    0.000 {built-in method numpy.core.umath.seterrobj}
#        40    0.000    0.000    0.000    0.000 {built-in method repaint}
#       164    0.000    0.000    0.000    0.000 {built-in method time.time}
#        40    0.000    0.000    0.001    0.000 {built-in method update_path_extents}
#        20    0.856    0.043    0.856    0.043 {built-in method write_png}
#        60    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#        60    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#     12212    0.003    0.000    0.003    0.000 {method 'add' of 'set' objects}
#     30200    0.019    0.000    0.148    0.000 {method 'all' of 'numpy.ndarray' objects}
#       260    0.000    0.000    0.003    0.000 {method 'any' of 'numpy.ndarray' objects}
#     27049    0.004    0.000    0.004    0.000 {method 'append' of 'list' objects}
#        80    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      4002    0.001    0.000    0.001    0.000 {method 'bit_length' of 'int' objects}
#      1984    0.003    0.000    0.003    0.000 {method 'clear' of 'FT2Font' objects}
#       156    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#        20    0.000    0.000    0.000    0.000 {method 'clip' of 'numpy.ndarray' objects}
#        20    0.026    0.001    0.026    0.001 {method 'close' of '_io.BufferedWriter' objects}
#        39    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#       120    0.002    0.000    0.002    0.000 {method 'compress' of 'numpy.ndarray' objects}
#       117    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#       664    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        40    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.generic' objects}
#     27142    0.070    0.000    0.070    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        39    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#      2944    0.003    0.000    0.003    0.000 {method 'count' of 'str' objects}
#        39    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       960    0.030    0.000    0.030    0.000 {method 'draw_glyphs_to_bitmap' of 'FT2Font' objects}
#       195    0.000    0.000    0.001    0.000 {method 'encode' of 'str' objects}
#       618    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       320    0.002    0.000    0.002    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#   4899691    0.579    0.000    0.579    0.000 {method 'get' of 'dict' objects}
#      1984    0.002    0.000    0.002    0.000 {method 'get_descent' of 'FT2Font' objects}
#       960    0.000    0.000    0.000    0.000 {method 'get_image' of 'FT2Font' objects}
#      1024    0.002    0.000    0.002    0.000 {method 'get_width_height' of 'FT2Font' objects}
#      6456    0.004    0.000    0.004    0.000 {method 'getrandbits' of '_random.Random' objects}
#        39    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        78    0.000    0.000    0.000    0.000 {method 'group' of '_sre.SRE_Match' objects}
#        39    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#        39    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#    651211    0.068    0.000    0.068    0.000 {method 'items' of 'dict' objects}
#       156    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        21    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#     19440    0.004    0.000    0.004    0.000 {method 'lower' of 'str' objects}
#      1304    0.001    0.000    0.007    0.000 {method 'max' of 'numpy.ndarray' objects}
#      1064    0.001    0.000    0.008    0.000 {method 'min' of 'numpy.ndarray' objects}
#       460    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#       120    0.002    0.000    0.002    0.000 {method 'ptp' of 'numpy.ndarray' objects}
#      1200    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#      2120    0.003    0.000    0.003    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     39108    0.154    0.000    0.154    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        60    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#     12212    0.002    0.000    0.002    0.000 {method 'remove' of 'set' objects}
#      2552    0.004    0.000    0.004    0.000 {method 'replace' of 'str' objects}
#      9972    0.019    0.000    0.019    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        60    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#      1920    0.008    0.000    0.008    0.000 {method 'round' of 'numpy.generic' objects}
#       240    0.001    0.000    0.001    0.000 {method 'round' of 'numpy.ndarray' objects}
#       720    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#       273    0.018    0.000    0.018    0.000 {method 'send' of 'zmq.backend.cython.socket.Socket' objects}
#      1984    0.005    0.000    0.005    0.000 {method 'set_size' of 'FT2Font' objects}
#      1984    0.145    0.000    0.145    0.000 {method 'set_text' of 'FT2Font' objects}
#        60    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#       180    0.001    0.000    0.001    0.000 {method 'sort' of 'list' objects}
#       512    0.001    0.000    0.001    0.000 {method 'split' of 'str' objects}
#      2342    0.001    0.000    0.001    0.000 {method 'strip' of 'str' objects}
#      1092    0.001    0.000    0.001    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#        60    0.001    0.000    0.001    0.000 {method 'take' of 'numpy.ndarray' objects}
#       195    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HASH' objects}
#      3421    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#        39    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#     12374    0.002    0.000    0.002    0.000 {method 'values' of 'dict' objects}
#        40    0.000    0.000    0.001    0.000 {method 'view' of 'numpy.generic' objects}
#        20    0.000    0.000    0.001    0.000 {method 'view' of 'numpy.ndarray' objects}
#       164    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        39    0.002    0.000    0.002    0.000 {zmq.backend.cython._poll.zmq_poll}
# C:\Users\Joe\Anaconda3\lib\site-packages\matplotlib\collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# C:\Users\Joe\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
#network = createGridGraph(30)

nx.get_edge_attributes(network,'weight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-8c91356d0ad6> in <module>()
#       3 #network = createGridGraph(30)
#       4
# ----> 5 nx.get_edge_attributes(network,'weight')
#
# NameError: name 'network' is not defined

# %%
minWeight = 5

network = createGridGraph(2)
correctWeightError(network)

for a in range(4):
    for x in range(3):
        print(str(a) + "-" + str(x))
        path = getPath(network)
        adjustWeights(network,path=path,minWeight=minWeight,weightAdjust=.7)
        #correctWeightError(network)

        #displayGraphPath(network,path)
    base = r"C:\Users\Joe\Documents\Joe\Google Drive\Coding\ipython\Highways\testing_folder\joe_"
    filename = base + str(a) + ".png"
  #  print(nx.get_edge_attributes(network,'weight'))
    saveImage(network,filename)

# %%
network = createGridGraph(3)


path = getPath(network)
print(path)

print(network.edges(data=True))
displayGraphPath(network,path,highlightPath=True)

displayGraphPath(network,path,highlightPath=False)
#adjustWeights(network,path)

for v in path:
    print(v)
    if not network.has_edge(*v):
           v=(v[1],v[0])
    network.get_edge_data(*v)['weight'] = 50 #network.get_edge_data(*v)['weight']*weightAdjust

    
    

displayGraphPath(network,path,highlightPath=False)

print(network.edges(data=True))
